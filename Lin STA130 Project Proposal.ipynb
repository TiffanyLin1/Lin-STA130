# %%
# Analysis #1: Does the number of close friends Canadians have impact their satisfaction with their lives? 

# I plan to explore the variables CONNECTION_social_num_close_friends_grouped and WELLNESS_life_satisfaction, since these
# variables directly quantify the amount of close friends and life satisfaction, respectively, each respondent feels.
# Respondents can be described as having 0, 1-2, 3-4, or 5+ close friends and can rate their personal satisfaction with
# their life as a whole on a scale of 1 to 10, with 1 as the lowest and 10 as the highest.  In this situation, the
# independent input variable would be the amount of close friends, and the dependent outcome variable would be the level of
# satisfaction in life. 

# I would like to use a bar plot to visualize the distribution of the friend categories because it would
# allow me to see the frequency of people in each group and assess whether my findings for each group could be considered
# applicable to the whole Canadian population based on whether the sample size is large enough.

# I would also like to use boxplots to visualize the distribution of life satisfaction for each friend category because it
# would allow me to compare the distributions of life satisfaction across groups of differing numbers of close friends.  It
# would also allow me to find each group's median satisfaction, the quartiles for the data, and any outliers the data has.

# I plan to analyze whether there is a significant relationship between Canadians' number of close friends and their life
# satisfaction by finding the median satisfaction for each friend category and constructing a 95% confidence interval using
# bootstrapping of the data for these medians.  With bootstrapping, many simulations are run where samples that are
# independent, random, of the same size as the category's size, and with replacement are be taken of the respondents in each
# friend category.  Then, the median satisfaction rating is found for each of these new samples, and the 2.5th and 97.5th
# percentiles are taken from the distribution of new sample medians to create the 95% confidence interval of the population
# median satisfaction rating for each category.  This is an interval that has a 95% possibility of capturing the population
# median satisfaction rating for that category.  Using these intervals, I can assess whether an increase in the amount of
# friends one has can have a significant impact on their life satisfaction by seeing whether the 95% confidence intervals of
# two adjacent categories intersect at all.  If they do not intersect, then I can conclude that there is a relationship
# between Canadians' number of friends and their life satisfaction.

# In my analysis, I can see whether there is a significant increase (or possibly decrease) in median life satisfaction
# across adjacent friend categories.  Specifically, I can see whether an increase in the number of close friends from 0 to
# 1-2, 1-2 to 3-4, and 3-4 to 5+ result in a significant increase or decrease in life satisfaction.  I can also find a
# potential optimal number of close friends, calculating based on the category with the highest median life satisfaction
# and seeing whether that result appears to be statistically significant.  In this analysis, I would assume that the
# person's family, mental and physical health, career, living conditions, etc. are not confounding factors with their
# satisfaction with life (this is addressed through random sampling from the Canadian population).  Assuming that the people
# surveyed were randomly sampled from the Canadian population also helps me apply my analysis to the Canadian population.
# Additionally, this analysis can only be applied to the Canadian population because only Canadians had been surveyed for
# the data.

# I hypothesize that the number of close friends Canadians have has a significant positive relationship with their
# satisfaction with life across all adjacent categories.  Whatever my findings may be, I can apply them to my research
# question by finding whether any significant relationship exists between the two variables, and if such a relationship does
# exist, what its strength and direction is and whether it can be applied between every friend category.  Using this
# information, I can answer the research question in a detailed and nuanced way.



# Analysis #2: Does playing board games impact happiness in Canadians?
 
# I plan to explore the variables CONNECTION_activities_board_games_p3m and WELLNESS_subjective_happiness_scale_happy, since
# the first variable measures the frequency at which survey respondents play board games, and the second variable measures
# their self-assessed happiness.  Respondents can be described as having played board games as sparsely as not in the last 3
# months to as often as daily or almost daily, and they can also rate their happiness on a scale from 1 to 7, with 1 as the
# lowest and 7 as the highest.  Here, the independent input variable would be the frequency of board game play, and the
# dependent outcome variable would be the level of happiness. 

# I would use a bar plot to visualize the board game categories because it would allow me to see the frequency of people in
# each category and see whether each sample size is large enough for the conclusions about its group to be considered
# applicable to the Canadian population.

# I would also use boxplots to visualize the distribution of happiness for each individual board game category because it
# would allow me to easily compare the distributions of happiness across groups who play board games at different
# frequencies.  It would also allow me to find each group's median happiness, the quartiles for the data, and any outliers
# the data has.

# Similarly to the previous analysis, I plan to analyze whether there is a significant relationship between the frequency of
# board game play and happiness in Canadians by finding the median happiness for each board game category and constructing a
# 95% confidence interval of each of the medians using bootstrapping.  With bootstrapping, many simulations would be run
# where samples that are independent, random, of the same size as the category's size, and with replacement would be taken
# of the people in each board game category.  Then, the median happiness score is found for each of these new samples, and
# the 2.5th and 97.5th percentiles are recorded from the distribution of sample medians to create the 95% confidence
# interval of the population median happiness score for each category.  This interval has a 95% chance of capturing the
# population median happiness score for that category.  Using these intervals, I can assess whether an increase in the
# frequency of board game play in Canadians has a significant impact on their overall happiness by seeing whether the 95%
# confidence intervals of two adjacent categories cross each other.  If they do not cross, then I can conclude that there is
# a relationship between the variables.

# In my analysis, I will assess whether there is a significant change in median happiness across the different board game
# play categories.  Looking at the categories from as infrequent as "not in the past 3 months" to as frequent as "daily or
# almost daily", I can look at 2 adjacent categories and see whether a significant change in median happiness exists between
# them. In the analysis, I would have to assume that the person's family, friends, initial mental and physical health,
# career, living conditions, etc. are not confounding factors for their happiness in life.  I must assume that the people
# surveyed were randomly sampled from the Canadian population in order to apply my findings to the Canadian population, and
# also to be able to assume the previous assumption.  In addition, this analysis would only be applicable to the Canadian
# population, since only Canadians had been surveyed for the data.

# I hypothesize that there is an overall relationship between Canadians' frequency of board game play and their
# happiness, and that this relationship is positive.  My work can be applied to my research question by answering the
# question of whether there exists any significant relationship between the variables, and if so, showing the strength and
# direction of this relationship.  Additionally, I can observe whether there exists a relationship between the variables in
# just two adjacent board game play categories at a time.



# Analysis #3:  Do hugs impact physical health in Canadians?

# I plan to explore the variables CONNECTION_activities_hug_p3m and WELLNESS_self_rated_physical_health, since they measure
# how often a survey respondent hugs someone and their rating of their physical health, respectively.  The respondents could
# indicate how often they hug others on a scale from "not in the past 3 months" to "daily or almost daily" and could rate
# their physical health on a scale from "poor" to "excellent".  In this analysis, the independent input variable would be
# the frequency of hugs given, and the dependent outcome variable would be the physical health rating.

# I would use a bar plot to visualize the distribution of people within the hug frequency categories for 2 reasons.
# Firstly, this variable is categorical, which bar plots are suited for visualizing.  Secondly, it would allow me to view
# the frequency of people that fall within each category.  I can use the second piece of information to see whether each
# individual sample size would be large enough to be considered applicable to the entire Canadian population.

# Before visualizing the respondents' physical health ratings, I would associate each response with a number, with the
# poorest being 1 and the best being 5.  Then, I would visualize this converted numerical data with boxplots, with one
# boxplot showing the distributions, the median, quartiles, and outliers of (converted numerical) physical health ratings
# for each hug frequency category.  This way, I can compare the distributions and sample statistics of each category with
# all the other categories.

# Similarly to the last 2 analyses, I plan to analyze whether there is a significant relationship between the frequency of
# hugs given by Canadians and their (converted numerical) ratings of their physical health by finding the median health
# rating for each hug category and constructing a 95% confidence interval of the medians using bootstrapping.  With
# bootstrapping, many simulations are run where samples that are independent, random, of the same size as the category's
# size, and with replacement are be taken of the respondents in each hug frequency category.  Then, the median physical
# health rating is found for all of these new samples, and the 2.5th and 97.5th percentiles are taken from the distribution
# of these new sample medians to create the 95% confidence interval of the population median physical health rating for each
# hug frequency category, an interval that has a 95% possibility of capturing the population median physical health
# rating for that category.  Using these intervals, I can analyze whether an increase in the frequency of hugs given by
# Canadians has a significant impact on their physical health ratings by seeing whether the 95% confidence intervals of two
# adjacent categories intersect each other at all.  If they do not intersect at all, then I can conclude that there is a
# relationship between the variables.

# In my analysis, I will evaluate whether there is a significant change in median physical health ratings across the
# different hug frequency categories.  Observing the categories from as infrequent as "not in the past 3 months" to as
# frequent as "daily or almost daily", I can focus on 2 adjacent categories at a time and assess whether there is a
# significant change in median physical health between them.  In the analysis, I would have to assume that the person's
# family, friends, mental health, career, living conditions, etc. are not confounding factors influencing their physical
# health.  I would have to assume that the people surveyed were truly randomly sampled from the Canadian population for this
# analysis to be applicable to the Canadian population.  Also, assuming the people surveyed are randomly sampled from the
# Canadian population would cancel the effect of the outside influences mentioned above on one's physical health.
# Additionally, I cannot directly assess each respondent's true physical health, so I must assume that their self-reported
# rating of their physical health is what their health is truly like.  Finally, the Canadian population is the only
# population I can apply my analysis on, since only Canadians were surveyed in the data collection.

# I hypothesize that there is a positive relationship between frequency of hugs given and physical health.  My research 
# results can be applied to my initial question by showing whether there is a significant relationship between the
# two variables, and if so, showing this relationship's strength and direction.  Additionally, I can analyze whether
# there is a relationship between the two variables in two adjacent hug frequency categories at a time.
